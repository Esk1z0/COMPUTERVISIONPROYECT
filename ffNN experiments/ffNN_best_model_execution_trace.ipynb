# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
EXPERIMENT_NAME='ffNN/ffNN_best_model_execution_trace'
assert(not EXPERIMENT_NAME is None)

import tensorflow as tf
import uuid
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import warnings
import rasterio
import json
import glob
import shutil

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Activation, Rescaling
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.layers import Dense, Flatten, Input, Dropout, BatchNormalization
from tensorflow.keras.callbacks import TerminateOnNaN, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import confusion_matrix

# %matplotlib inline
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-01-13 19:52:17.313874: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-13 19:52:17.443038: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-13 19:52:17.501065: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8473] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-13 19:52:17.518248: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1471] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-13 19:52:17.603261: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768333940.094724     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768333940.246243     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768333940.250697     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
PROJECT_PATH = "/workspace/COMPUTERVISIONPROYECT"
DATASET_NAME = 'stratified'

# XVIEW_RECOGNITION_PATH = "./data/xview_recognition/"
XVIEW_RECOGNITION_PATH = os.path.join(PROJECT_PATH, "data/xview_recognition")

EXPERIMENT_PATH = os.path.join(PROJECT_PATH, "experiment_results", EXPERIMENT_NAME)
assert(not os.path.exists(EXPERIMENT_PATH))
if not os.path.exists(EXPERIMENT_PATH):
    os.mkdir(EXPERIMENT_PATH)
CHECKPOINT_DIR = os.path.join(EXPERIMENT_PATH, 'model_checkpoints')
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
BEST_WEIGHTS_FILENAME_PATTERN = os.path.join(CHECKPOINT_DIR, 'epoch_{epoch:03d}-val_loss_{val_loss:.4f}.keras')
MODEL_PATH = os.path.join(EXPERIMENT_PATH, 'model.keras')

TRAIN_SET_FILENAME = '_'.join([DATASET_NAME, 'train.tfrecord'])
VALIDATION_SET_FILENAME = '_'.join([DATASET_NAME, 'validation.tfrecord'])
TRAIN_SET_PATH = os.path.join(XVIEW_RECOGNITION_PATH, TRAIN_SET_FILENAME)
VALIDATION_SET_PATH = os.path.join(XVIEW_RECOGNITION_PATH, VALIDATION_SET_FILENAME)

## Hyperparameters
BATCH_SIZE = 128
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 0
DROPOUT_RATE = 0.1
REGULARIZER_PENALTY = None
EPOCHS = 200

categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %% [markdown]
# # Required classes and functions

# %%
class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[3.2*pow(len(categories), 0.5), 2.4*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(15-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

# 0. La usamos para las imágenes de test
def load_geoimage(filename_tensor):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    filename = filename_tensor
    src_raster = rasterio.open(filename, 'r')

    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# 1. Función para decodificar los ejemplos del archivo
def _parse_image_function(example_proto):
    feature_description = {
        'height': tf.io.FixedLenFeature([], tf.int64),
        'width': tf.io.FixedLenFeature([], tf.int64),
        'depth': tf.io.FixedLenFeature([], tf.int64),
        'category_id': tf.io.FixedLenFeature([], tf.int64),
        'image_raw': tf.io.FixedLenFeature([], tf.string),
    }
    
    features = tf.io.parse_single_example(example_proto, feature_description)
    
    image = tf.io.decode_raw(features['image_raw'], out_type=tf.uint8)
    shape = [features['height'], features['width'], features['depth']]
    image = tf.reshape(image, shape)
    image = tf.cast(image, tf.float32)
    
    image = tf.image.resize(image, [224, 224])
    
    category_id = tf.cast(features['category_id'], tf.int32)
    label = tf.one_hot(category_id, depth=len(categories))
    
    return image, label

# 2. Función para crear el dataset
def create_tfrecord_dataset(filenames, batch_size, do_shuffle=False):
    # Lee los archivos TFRecord. Puede leer de múltiples archivos en paralelo.
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=tf.data.AUTOTUNE)
    
    dataset = dataset.map(_parse_image_function, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.cache()
    
    if do_shuffle:
        dataset = dataset.shuffle(buffer_size=1000)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    
    return dataset

# %% [markdown]
# # Datasets definition

# %%
train_dataset = create_tfrecord_dataset([TRAIN_SET_PATH], BATCH_SIZE, do_shuffle=True)
valid_dataset = create_tfrecord_dataset([VALIDATION_SET_PATH], BATCH_SIZE)
# Out:
# I0000 00:00:1768333953.830304     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768333953.833288     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768333953.835533     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768333953.949991     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768333953.950883     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1768333953.951704     135 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-13 19:52:33.953032: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11478 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5070 Ti, pci bus id: 0000:01:00.0, compute capability: 12.0

# %%
y_train_labels = []
for _,label_idxs in train_dataset:
    y_train_labels += list(label_idxs.numpy().argmax(axis=1))

index,freqs = np.unique(y_train_labels, return_counts=True)
categories_count = pd.Series(freqs, index=[categories[idx] for idx in index], name='Size').sort_values(ascending=False)

categories_count
# Out:
# 2026-01-13 19:52:37.747192: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Building              3235
# Small car             2992
# Truck                 1989
# Bus                   1591
# Shipping container    1371
# Storage tank          1322
# Dump truck            1112
# Motorboat              962
# Excavator              710
# Fishing vessel         635
# Cargo plane            571
# Pylon                  281
# Helipad                100
# Name: Size, dtype: int64

# %%
data_augmentation = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.1),
])

# %% [markdown]
# # Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
print('Load model')

model = Sequential(name=EXPERIMENT_NAME)
model.add(Input(shape=(224, 224, 3)))
model.add(Rescaling(1./255))
model.add(data_augmentation)
model.add(Flatten())
model.add(Activation('relu'))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(DROPOUT_RATE))

model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(DROPOUT_RATE))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(DROPOUT_RATE))

model.add(Dense(len(categories), activation='softmax'))

model.summary()
# Out:
# Load model
# Model: "ffNN/ffNN_best_model_execution_trace"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  flatten (Flatten)           (None, 150528)            0
#
#  activation (Activation)     (None, 150528)            0
#
#  dense (Dense)               (None, 512)               77070848
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_2 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Bat  (None, 128)               512
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 13)                1677
#
# =================================================================
# Total params: 77240333 (294.65 MB)
# Trainable params: 77238541 (294.64 MB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________

# %%
opt = Adam(learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
model.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Callbacks
model_checkpoint = ModelCheckpoint(
    filepath=BEST_WEIGHTS_FILENAME_PATTERN,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True
)
reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-6)
terminate = TerminateOnNaN()
early_stop = EarlyStopping('val_accuracy', patience=EPOCHS, verbose=1, restore_best_weights=False)
callbacks = [model_checkpoint, reduce_lr, early_stop, terminate]

# %%
print('Training model')
h = model.fit(train_dataset, 
              validation_data=valid_dataset, 
              epochs=EPOCHS, 
              callbacks=callbacks, 
              verbose=1)

checkpoints = glob.glob(os.path.join(CHECKPOINT_DIR, '*.keras'))

if checkpoints:
    # Copiamos el mejor modelo en la ruta {EXPERIMENT_PATH}/model.keras
    # Ordenar los archivos por el valor de 'val_loss' (que está en el nombre)
    # y coger el primero (el que tenga el valor más bajo)
    BEST_WEIGHTS_FILENAME = min(checkpoints, key=lambda x: float(x.split('val_loss_')[1].replace('.keras', '')))
    shutil.copy(BEST_WEIGHTS_FILENAME, MODEL_PATH)
    print(f"El mejor modelo se encuentra en: {MODEL_PATH}")
else:
    print("No se encontraron checkpoints.")
# Out:
# Training model
# Epoch 1/200
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768333980.692441     235 service.cc:146] XLA service 0x7f5397d45030 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1768333980.692457     235 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 5070 Ti, Compute Capability 12.0
# 2026-01-13 19:53:00.697453: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-01-13 19:53:00.732572: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90701
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# I0000 00:00:1768333980.787899     235 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
#       4/Unknown - 3s 26ms/step - loss: 2.8544 - accuracy: 0.1113
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
#     131/Unknown - 7s 31ms/step - loss: 2.1461 - accuracy: 0.2530
# 2026-01-13 19:53:05.249911: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2026-01-13 19:53:05.249993: I tensorflow/core/framework/local_rendezvous.cc:427] Local rendezvous send item cancelled. Key hash: 5297050723004901730
# 2026-01-13 19:53:05.250061: I tensorflow/core/framework/local_rendezvous.cc:427] Local rendezvous send item cancelled. Key hash: 2677040960911628375
# 2026-01-13 19:53:05.250077: I tensorflow/core/framework/local_rendezvous.cc:427] Local rendezvous send item cancelled. Key hash: 6899617358126935687
# Epoch 1: val_loss improved from inf to 2.14509, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_001-val_loss_2.1451.keras
# 132/132 [==============================] - 7s 36ms/step - loss: 2.1446 - accuracy: 0.2535 - val_loss: 2.1451 - val_accuracy: 0.2603 - lr: 0.0010
# Epoch 2/200
# 2026-01-13 19:53:05.753944: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 130/132 [============================>.] - ETA: 0s - loss: 1.9002 - accuracy: 0.3407
# Epoch 2: val_loss improved from 2.14509 to 2.11483, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_002-val_loss_2.1148.keras
# 132/132 [==============================] - 4s 32ms/step - loss: 1.9002 - accuracy: 0.3405 - val_loss: 2.1148 - val_accuracy: 0.2752 - lr: 0.0010
# Epoch 3/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.8042 - accuracy: 0.3756
# Epoch 3: val_loss improved from 2.11483 to 2.02617, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_003-val_loss_2.0262.keras
# 132/132 [==============================] - 4s 32ms/step - loss: 1.8031 - accuracy: 0.3759 - val_loss: 2.0262 - val_accuracy: 0.2955 - lr: 0.0010
# Epoch 4/200
# 132/132 [==============================] - ETA: 0s - loss: 1.7375 - accuracy: 0.3977
# Epoch 4: val_loss did not improve from 2.02617
# 132/132 [==============================] - 4s 27ms/step - loss: 1.7375 - accuracy: 0.3977 - val_loss: 2.0545 - val_accuracy: 0.3024 - lr: 0.0010
# Epoch 5/200
# 132/132 [==============================] - ETA: 0s - loss: 1.6936 - accuracy: 0.4180
# Epoch 5: val_loss improved from 2.02617 to 1.83417, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_005-val_loss_1.8342.keras
# 132/132 [==============================] - 4s 27ms/step - loss: 1.6936 - accuracy: 0.4180 - val_loss: 1.8342 - val_accuracy: 0.3648 - lr: 0.0010
# Epoch 6/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.6635 - accuracy: 0.4280
# Epoch 6: val_loss did not improve from 1.83417
# 132/132 [==============================] - 4s 33ms/step - loss: 1.6642 - accuracy: 0.4280 - val_loss: 1.9298 - val_accuracy: 0.3312 - lr: 0.0010
# Epoch 7/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.6270 - accuracy: 0.4473
# Epoch 7: val_loss improved from 1.83417 to 1.65204, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_007-val_loss_1.6520.keras
# 132/132 [==============================] - 4s 33ms/step - loss: 1.6277 - accuracy: 0.4468 - val_loss: 1.6520 - val_accuracy: 0.4283 - lr: 0.0010
# Epoch 8/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.6055 - accuracy: 0.4485
# Epoch 8: val_loss did not improve from 1.65204
# 132/132 [==============================] - 4s 34ms/step - loss: 1.6046 - accuracy: 0.4488 - val_loss: 2.1449 - val_accuracy: 0.3077 - lr: 0.0010
# Epoch 9/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.5790 - accuracy: 0.4643
# Epoch 9: val_loss did not improve from 1.65204
# 132/132 [==============================] - 5s 34ms/step - loss: 1.5785 - accuracy: 0.4648 - val_loss: 2.0974 - val_accuracy: 0.3131 - lr: 0.0010
# Epoch 10/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.5531 - accuracy: 0.4682
# Epoch 10: val_loss did not improve from 1.65204
# 132/132 [==============================] - 4s 34ms/step - loss: 1.5525 - accuracy: 0.4686 - val_loss: 2.2494 - val_accuracy: 0.2960 - lr: 0.0010
# Epoch 11/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.5421 - accuracy: 0.4706
# Epoch 11: val_loss did not improve from 1.65204
# 132/132 [==============================] - 4s 33ms/step - loss: 1.5430 - accuracy: 0.4704 - val_loss: 1.9450 - val_accuracy: 0.3589 - lr: 0.0010
# Epoch 12/200
# 132/132 [==============================] - ETA: 0s - loss: 1.5048 - accuracy: 0.4859
# Epoch 12: val_loss did not improve from 1.65204
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 132/132 [==============================] - 4s 33ms/step - loss: 1.5048 - accuracy: 0.4859 - val_loss: 1.8093 - val_accuracy: 0.3872 - lr: 0.0010
# Epoch 13/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.4577 - accuracy: 0.5053
# Epoch 13: val_loss improved from 1.65204 to 1.65167, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_013-val_loss_1.6517.keras
# 132/132 [==============================] - 5s 34ms/step - loss: 1.4576 - accuracy: 0.5057 - val_loss: 1.6517 - val_accuracy: 0.4299 - lr: 5.0000e-04
# Epoch 14/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.4365 - accuracy: 0.5128
# Epoch 14: val_loss improved from 1.65167 to 1.44362, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_014-val_loss_1.4436.keras
# 132/132 [==============================] - 4s 31ms/step - loss: 1.4371 - accuracy: 0.5126 - val_loss: 1.4436 - val_accuracy: 0.4981 - lr: 5.0000e-04
# Epoch 15/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.4319 - accuracy: 0.5093
# Epoch 15: val_loss did not improve from 1.44362
# 132/132 [==============================] - 4s 33ms/step - loss: 1.4323 - accuracy: 0.5093 - val_loss: 1.4938 - val_accuracy: 0.4891 - lr: 5.0000e-04
# Epoch 16/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.4195 - accuracy: 0.5158
# Epoch 16: val_loss did not improve from 1.44362
# 132/132 [==============================] - 4s 33ms/step - loss: 1.4200 - accuracy: 0.5159 - val_loss: 1.6367 - val_accuracy: 0.4325 - lr: 5.0000e-04
# Epoch 17/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3965 - accuracy: 0.5280
# Epoch 17: val_loss did not improve from 1.44362
# 132/132 [==============================] - 5s 34ms/step - loss: 1.3979 - accuracy: 0.5276 - val_loss: 1.5745 - val_accuracy: 0.4597 - lr: 5.0000e-04
# Epoch 18/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3937 - accuracy: 0.5236
# Epoch 18: val_loss did not improve from 1.44362
# 132/132 [==============================] - 4s 32ms/step - loss: 1.3938 - accuracy: 0.5234 - val_loss: 1.5964 - val_accuracy: 0.4597 - lr: 5.0000e-04
# Epoch 19/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3866 - accuracy: 0.5254
# Epoch 19: val_loss did not improve from 1.44362
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 132/132 [==============================] - 4s 34ms/step - loss: 1.3873 - accuracy: 0.5252 - val_loss: 1.6771 - val_accuracy: 0.4416 - lr: 5.0000e-04
# Epoch 20/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3653 - accuracy: 0.5355
# Epoch 20: val_loss improved from 1.44362 to 1.43029, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_020-val_loss_1.4303.keras
# 132/132 [==============================] - 5s 36ms/step - loss: 1.3653 - accuracy: 0.5355 - val_loss: 1.4303 - val_accuracy: 0.5125 - lr: 2.5000e-04
# Epoch 21/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3483 - accuracy: 0.5406
# Epoch 21: val_loss improved from 1.43029 to 1.42064, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_021-val_loss_1.4206.keras
# 132/132 [==============================] - 5s 35ms/step - loss: 1.3484 - accuracy: 0.5403 - val_loss: 1.4206 - val_accuracy: 0.5093 - lr: 2.5000e-04
# Epoch 22/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3396 - accuracy: 0.5406
# Epoch 22: val_loss did not improve from 1.42064
# 132/132 [==============================] - 4s 32ms/step - loss: 1.3405 - accuracy: 0.5400 - val_loss: 1.5437 - val_accuracy: 0.4688 - lr: 2.5000e-04
# Epoch 23/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3377 - accuracy: 0.5429
# Epoch 23: val_loss improved from 1.42064 to 1.39031, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_023-val_loss_1.3903.keras
# 132/132 [==============================] - 4s 34ms/step - loss: 1.3377 - accuracy: 0.5432 - val_loss: 1.3903 - val_accuracy: 0.5248 - lr: 2.5000e-04
# Epoch 24/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3267 - accuracy: 0.5504
# Epoch 24: val_loss did not improve from 1.39031
# 132/132 [==============================] - 4s 33ms/step - loss: 1.3265 - accuracy: 0.5508 - val_loss: 1.5410 - val_accuracy: 0.4784 - lr: 2.5000e-04
# Epoch 25/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.3171 - accuracy: 0.5553
# Epoch 25: val_loss did not improve from 1.39031
# 132/132 [==============================] - 4s 33ms/step - loss: 1.3184 - accuracy: 0.5551 - val_loss: 1.4450 - val_accuracy: 0.5083 - lr: 2.5000e-04
# Epoch 26/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3206 - accuracy: 0.5511
# Epoch 26: val_loss did not improve from 1.39031
# 132/132 [==============================] - 4s 33ms/step - loss: 1.3214 - accuracy: 0.5506 - val_loss: 1.4320 - val_accuracy: 0.5195 - lr: 2.5000e-04
# Epoch 27/200
# 132/132 [==============================] - ETA: 0s - loss: 1.3193 - accuracy: 0.5502
# Epoch 27: val_loss did not improve from 1.39031
# 132/132 [==============================] - 4s 34ms/step - loss: 1.3193 - accuracy: 0.5502 - val_loss: 1.4283 - val_accuracy: 0.5136 - lr: 2.5000e-04
# Epoch 28/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.3066 - accuracy: 0.5521
# Epoch 28: val_loss did not improve from 1.39031
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 132/132 [==============================] - 4s 32ms/step - loss: 1.3065 - accuracy: 0.5522 - val_loss: 1.4440 - val_accuracy: 0.4976 - lr: 2.5000e-04
# Epoch 29/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2925 - accuracy: 0.5592
# Epoch 29: val_loss did not improve from 1.39031
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2925 - accuracy: 0.5592 - val_loss: 1.6454 - val_accuracy: 0.4517 - lr: 1.2500e-04
# Epoch 30/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2769 - accuracy: 0.5640
# Epoch 30: val_loss did not improve from 1.39031
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2771 - accuracy: 0.5637 - val_loss: 1.4145 - val_accuracy: 0.5189 - lr: 1.2500e-04
# Epoch 31/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2787 - accuracy: 0.5611
# Epoch 31: val_loss did not improve from 1.39031
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2787 - accuracy: 0.5611 - val_loss: 1.4252 - val_accuracy: 0.5157 - lr: 1.2500e-04
# Epoch 32/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2693 - accuracy: 0.5659
# Epoch 32: val_loss did not improve from 1.39031
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2693 - accuracy: 0.5659 - val_loss: 1.4210 - val_accuracy: 0.5115 - lr: 1.2500e-04
# Epoch 33/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2758 - accuracy: 0.5661
# Epoch 33: val_loss did not improve from 1.39031
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2752 - accuracy: 0.5659 - val_loss: 1.4112 - val_accuracy: 0.5232 - lr: 1.2500e-04
# Epoch 34/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2516 - accuracy: 0.5753
# Epoch 34: val_loss improved from 1.39031 to 1.36410, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_034-val_loss_1.3641.keras
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2516 - accuracy: 0.5746 - val_loss: 1.3641 - val_accuracy: 0.5365 - lr: 6.2500e-05
# Epoch 35/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2458 - accuracy: 0.5740
# Epoch 35: val_loss improved from 1.36410 to 1.34914, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_035-val_loss_1.3491.keras
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2453 - accuracy: 0.5739 - val_loss: 1.3491 - val_accuracy: 0.5349 - lr: 6.2500e-05
# Epoch 36/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2481 - accuracy: 0.5713
# Epoch 36: val_loss improved from 1.34914 to 1.33510, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_036-val_loss_1.3351.keras
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2481 - accuracy: 0.5713 - val_loss: 1.3351 - val_accuracy: 0.5504 - lr: 6.2500e-05
# Epoch 37/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2546 - accuracy: 0.5736
# Epoch 37: val_loss did not improve from 1.33510
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2545 - accuracy: 0.5735 - val_loss: 1.3515 - val_accuracy: 0.5392 - lr: 6.2500e-05
# Epoch 38/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2413 - accuracy: 0.5755
# Epoch 38: val_loss did not improve from 1.33510
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2413 - accuracy: 0.5755 - val_loss: 1.3594 - val_accuracy: 0.5387 - lr: 6.2500e-05
# Epoch 39/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2404 - accuracy: 0.5763
# Epoch 39: val_loss improved from 1.33510 to 1.33154, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_039-val_loss_1.3315.keras
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2404 - accuracy: 0.5763 - val_loss: 1.3315 - val_accuracy: 0.5525 - lr: 6.2500e-05
# Epoch 40/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2442 - accuracy: 0.5773
# Epoch 40: val_loss did not improve from 1.33154
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2442 - accuracy: 0.5773 - val_loss: 1.3833 - val_accuracy: 0.5248 - lr: 6.2500e-05
# Epoch 41/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2385 - accuracy: 0.5764
# Epoch 41: val_loss did not improve from 1.33154
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2390 - accuracy: 0.5762 - val_loss: 1.3789 - val_accuracy: 0.5333 - lr: 6.2500e-05
# Epoch 42/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2400 - accuracy: 0.5770
# Epoch 42: val_loss improved from 1.33154 to 1.31837, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_042-val_loss_1.3184.keras
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2399 - accuracy: 0.5775 - val_loss: 1.3184 - val_accuracy: 0.5520 - lr: 6.2500e-05
# Epoch 43/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2397 - accuracy: 0.5778
# Epoch 43: val_loss did not improve from 1.31837
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2397 - accuracy: 0.5778 - val_loss: 1.3378 - val_accuracy: 0.5435 - lr: 6.2500e-05
# Epoch 44/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2348 - accuracy: 0.5767
# Epoch 44: val_loss did not improve from 1.31837
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2348 - accuracy: 0.5767 - val_loss: 1.3504 - val_accuracy: 0.5435 - lr: 6.2500e-05
# Epoch 45/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2301 - accuracy: 0.5813
# Epoch 45: val_loss did not improve from 1.31837
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2308 - accuracy: 0.5808 - val_loss: 1.3460 - val_accuracy: 0.5397 - lr: 3.1250e-05
# Epoch 46/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2234 - accuracy: 0.5795
# Epoch 46: val_loss did not improve from 1.31837
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2234 - accuracy: 0.5795 - val_loss: 1.3705 - val_accuracy: 0.5419 - lr: 3.1250e-05
# Epoch 47/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2197 - accuracy: 0.5863
# Epoch 47: val_loss did not improve from 1.31837
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2197 - accuracy: 0.5863 - val_loss: 1.3321 - val_accuracy: 0.5397 - lr: 3.1250e-05
# Epoch 48/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2189 - accuracy: 0.5834
# Epoch 48: val_loss did not improve from 1.31837
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2189 - accuracy: 0.5834 - val_loss: 1.3567 - val_accuracy: 0.5392 - lr: 3.1250e-05
# Epoch 49/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2197 - accuracy: 0.5852
# Epoch 49: val_loss did not improve from 1.31837
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2217 - accuracy: 0.5846 - val_loss: 1.3500 - val_accuracy: 0.5392 - lr: 3.1250e-05
# Epoch 50/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2225 - accuracy: 0.5861
# Epoch 50: val_loss improved from 1.31837 to 1.31224, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_050-val_loss_1.3122.keras
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2225 - accuracy: 0.5860 - val_loss: 1.3122 - val_accuracy: 0.5525 - lr: 1.5625e-05
# Epoch 51/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2205 - accuracy: 0.5804
# Epoch 51: val_loss did not improve from 1.31224
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2205 - accuracy: 0.5804 - val_loss: 1.3152 - val_accuracy: 0.5520 - lr: 1.5625e-05
# Epoch 52/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2172 - accuracy: 0.5883
# Epoch 52: val_loss did not improve from 1.31224
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2171 - accuracy: 0.5881 - val_loss: 1.3202 - val_accuracy: 0.5456 - lr: 1.5625e-05
# Epoch 53/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2179 - accuracy: 0.5870
# Epoch 53: val_loss did not improve from 1.31224
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2179 - accuracy: 0.5870 - val_loss: 1.3304 - val_accuracy: 0.5429 - lr: 1.5625e-05
# Epoch 54/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2171 - accuracy: 0.5817
# Epoch 54: val_loss did not improve from 1.31224
#
# Epoch 54: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2171 - accuracy: 0.5817 - val_loss: 1.3139 - val_accuracy: 0.5493 - lr: 1.5625e-05
# Epoch 55/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2075 - accuracy: 0.5912
# Epoch 55: val_loss improved from 1.31224 to 1.30551, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model_checkpoints/epoch_055-val_loss_1.3055.keras
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2075 - accuracy: 0.5912 - val_loss: 1.3055 - val_accuracy: 0.5541 - lr: 7.8125e-06
# Epoch 56/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2063 - accuracy: 0.5867
# Epoch 56: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2063 - accuracy: 0.5867 - val_loss: 1.3116 - val_accuracy: 0.5531 - lr: 7.8125e-06
# Epoch 57/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2219 - accuracy: 0.5832
# Epoch 57: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2220 - accuracy: 0.5830 - val_loss: 1.3146 - val_accuracy: 0.5525 - lr: 7.8125e-06
# Epoch 58/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2119 - accuracy: 0.5856
# Epoch 58: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2126 - accuracy: 0.5857 - val_loss: 1.3190 - val_accuracy: 0.5493 - lr: 7.8125e-06
# Epoch 59/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2116 - accuracy: 0.5813
# Epoch 59: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2123 - accuracy: 0.5815 - val_loss: 1.3188 - val_accuracy: 0.5509 - lr: 7.8125e-06
# Epoch 60/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2132 - accuracy: 0.5857
# Epoch 60: val_loss did not improve from 1.30551
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2122 - accuracy: 0.5862 - val_loss: 1.3146 - val_accuracy: 0.5509 - lr: 7.8125e-06
# Epoch 61/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2065 - accuracy: 0.5885
# Epoch 61: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2065 - accuracy: 0.5885 - val_loss: 1.3122 - val_accuracy: 0.5488 - lr: 3.9063e-06
# Epoch 62/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2113 - accuracy: 0.5873
# Epoch 62: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2111 - accuracy: 0.5875 - val_loss: 1.3174 - val_accuracy: 0.5493 - lr: 3.9063e-06
# Epoch 63/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2067 - accuracy: 0.5897
# Epoch 63: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2067 - accuracy: 0.5897 - val_loss: 1.3142 - val_accuracy: 0.5525 - lr: 3.9063e-06
# Epoch 64/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2073 - accuracy: 0.5873
# Epoch 64: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2073 - accuracy: 0.5873 - val_loss: 1.3103 - val_accuracy: 0.5541 - lr: 3.9063e-06
# Epoch 65/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2133 - accuracy: 0.5859
# Epoch 65: val_loss did not improve from 1.30551
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2123 - accuracy: 0.5863 - val_loss: 1.3162 - val_accuracy: 0.5493 - lr: 3.9063e-06
# Epoch 66/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2078 - accuracy: 0.5867
# Epoch 66: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2078 - accuracy: 0.5867 - val_loss: 1.3155 - val_accuracy: 0.5515 - lr: 1.9531e-06
# Epoch 67/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2106 - accuracy: 0.5859
# Epoch 67: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2106 - accuracy: 0.5859 - val_loss: 1.3140 - val_accuracy: 0.5504 - lr: 1.9531e-06
# Epoch 68/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2181 - accuracy: 0.5850
# Epoch 68: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2180 - accuracy: 0.5851 - val_loss: 1.3146 - val_accuracy: 0.5493 - lr: 1.9531e-06
# Epoch 69/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2110 - accuracy: 0.5896
# Epoch 69: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2099 - accuracy: 0.5901 - val_loss: 1.3146 - val_accuracy: 0.5541 - lr: 1.9531e-06
# Epoch 70/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2061 - accuracy: 0.5895
# Epoch 70: val_loss did not improve from 1.30551
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1e-06.
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2063 - accuracy: 0.5891 - val_loss: 1.3164 - val_accuracy: 0.5515 - lr: 1.9531e-06
# Epoch 71/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2116 - accuracy: 0.5839
# Epoch 71: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2118 - accuracy: 0.5840 - val_loss: 1.3176 - val_accuracy: 0.5483 - lr: 1.0000e-06
# Epoch 72/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2062 - accuracy: 0.5896
# Epoch 72: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2062 - accuracy: 0.5896 - val_loss: 1.3163 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 73/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2053 - accuracy: 0.5899
# Epoch 73: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2068 - accuracy: 0.5890 - val_loss: 1.3169 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 74/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2067 - accuracy: 0.5940
# Epoch 74: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2070 - accuracy: 0.5938 - val_loss: 1.3089 - val_accuracy: 0.5557 - lr: 1.0000e-06
# Epoch 75/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2025 - accuracy: 0.5891
# Epoch 75: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2030 - accuracy: 0.5887 - val_loss: 1.3139 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 76/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2116 - accuracy: 0.5859
# Epoch 76: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2122 - accuracy: 0.5859 - val_loss: 1.3165 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 77/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2061 - accuracy: 0.5906
# Epoch 77: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2061 - accuracy: 0.5906 - val_loss: 1.3144 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 78/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2053 - accuracy: 0.5906
# Epoch 78: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2060 - accuracy: 0.5906 - val_loss: 1.3152 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 79/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2051 - accuracy: 0.5911
# Epoch 79: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2042 - accuracy: 0.5914 - val_loss: 1.3179 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 80/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2080 - accuracy: 0.5911
# Epoch 80: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2085 - accuracy: 0.5914 - val_loss: 1.3181 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 81/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2015 - accuracy: 0.5946
# Epoch 81: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2020 - accuracy: 0.5943 - val_loss: 1.3142 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 82/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2069 - accuracy: 0.5882
# Epoch 82: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2069 - accuracy: 0.5882 - val_loss: 1.3164 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 83/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2008 - accuracy: 0.5895
# Epoch 83: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2010 - accuracy: 0.5894 - val_loss: 1.3116 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 84/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2058 - accuracy: 0.5877
# Epoch 84: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2071 - accuracy: 0.5872 - val_loss: 1.3123 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 85/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2097 - accuracy: 0.5893
# Epoch 85: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2097 - accuracy: 0.5893 - val_loss: 1.3173 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 86/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2048 - accuracy: 0.5876
# Epoch 86: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2048 - accuracy: 0.5876 - val_loss: 1.3152 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 87/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2055 - accuracy: 0.5891
# Epoch 87: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2055 - accuracy: 0.5891 - val_loss: 1.3153 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 88/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2027 - accuracy: 0.5881
# Epoch 88: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2040 - accuracy: 0.5878 - val_loss: 1.3156 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 89/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2164 - accuracy: 0.5859
# Epoch 89: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2155 - accuracy: 0.5864 - val_loss: 1.3183 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 90/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2213 - accuracy: 0.5893
# Epoch 90: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2220 - accuracy: 0.5889 - val_loss: 1.3155 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 91/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2017 - accuracy: 0.5884
# Epoch 91: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2017 - accuracy: 0.5884 - val_loss: 1.3109 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 92/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2042 - accuracy: 0.5898
# Epoch 92: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2046 - accuracy: 0.5892 - val_loss: 1.3153 - val_accuracy: 0.5477 - lr: 1.0000e-06
# Epoch 93/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2107 - accuracy: 0.5883
# Epoch 93: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2095 - accuracy: 0.5889 - val_loss: 1.3150 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 94/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2120 - accuracy: 0.5883
# Epoch 94: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2121 - accuracy: 0.5882 - val_loss: 1.3156 - val_accuracy: 0.5493 - lr: 1.0000e-06
# Epoch 95/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2067 - accuracy: 0.5899
# Epoch 95: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2082 - accuracy: 0.5890 - val_loss: 1.3132 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 96/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2083 - accuracy: 0.5905
# Epoch 96: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2083 - accuracy: 0.5905 - val_loss: 1.3143 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 97/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2048 - accuracy: 0.5901
# Epoch 97: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2044 - accuracy: 0.5902 - val_loss: 1.3147 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 98/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2026 - accuracy: 0.5953
# Epoch 98: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2031 - accuracy: 0.5950 - val_loss: 1.3195 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 99/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2075 - accuracy: 0.5865
# Epoch 99: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2076 - accuracy: 0.5866 - val_loss: 1.3150 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 100/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2082 - accuracy: 0.5865
# Epoch 100: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2082 - accuracy: 0.5865 - val_loss: 1.3153 - val_accuracy: 0.5531 - lr: 1.0000e-06
# Epoch 101/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2141 - accuracy: 0.5899
# Epoch 101: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2129 - accuracy: 0.5903 - val_loss: 1.3147 - val_accuracy: 0.5541 - lr: 1.0000e-06
# Epoch 102/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2104 - accuracy: 0.5846
# Epoch 102: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2104 - accuracy: 0.5846 - val_loss: 1.3141 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 103/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2094 - accuracy: 0.5889
# Epoch 103: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2096 - accuracy: 0.5887 - val_loss: 1.3124 - val_accuracy: 0.5531 - lr: 1.0000e-06
# Epoch 104/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2142 - accuracy: 0.5871
# Epoch 104: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 30ms/step - loss: 1.2135 - accuracy: 0.5870 - val_loss: 1.3166 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 105/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.1999 - accuracy: 0.5893
# Epoch 105: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2013 - accuracy: 0.5889 - val_loss: 1.3125 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 106/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2043 - accuracy: 0.5881
# Epoch 106: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2039 - accuracy: 0.5885 - val_loss: 1.3131 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 107/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2038 - accuracy: 0.5863
# Epoch 107: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2038 - accuracy: 0.5863 - val_loss: 1.3179 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 108/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2014 - accuracy: 0.5932
# Epoch 108: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2004 - accuracy: 0.5931 - val_loss: 1.3150 - val_accuracy: 0.5493 - lr: 1.0000e-06
# Epoch 109/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2042 - accuracy: 0.5875
# Epoch 109: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 31ms/step - loss: 1.2048 - accuracy: 0.5875 - val_loss: 1.3159 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 110/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2044 - accuracy: 0.5926
# Epoch 110: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2044 - accuracy: 0.5926 - val_loss: 1.3152 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 111/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2044 - accuracy: 0.5889
# Epoch 111: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2044 - accuracy: 0.5889 - val_loss: 1.3125 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 112/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2034 - accuracy: 0.5854
# Epoch 112: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2034 - accuracy: 0.5854 - val_loss: 1.3128 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 113/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2046 - accuracy: 0.5876
# Epoch 113: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2044 - accuracy: 0.5879 - val_loss: 1.3133 - val_accuracy: 0.5531 - lr: 1.0000e-06
# Epoch 114/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2083 - accuracy: 0.5883
# Epoch 114: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2083 - accuracy: 0.5883 - val_loss: 1.3163 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 115/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2092 - accuracy: 0.5870
# Epoch 115: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2093 - accuracy: 0.5874 - val_loss: 1.3135 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 116/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2007 - accuracy: 0.5904
# Epoch 116: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2007 - accuracy: 0.5904 - val_loss: 1.3127 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 117/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2052 - accuracy: 0.5909
# Epoch 117: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2052 - accuracy: 0.5910 - val_loss: 1.3155 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 118/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2128 - accuracy: 0.5863
# Epoch 118: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2128 - accuracy: 0.5863 - val_loss: 1.3160 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 119/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2088 - accuracy: 0.5874
# Epoch 119: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2088 - accuracy: 0.5874 - val_loss: 1.3163 - val_accuracy: 0.5493 - lr: 1.0000e-06
# Epoch 120/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2184 - accuracy: 0.5879
# Epoch 120: val_loss did not improve from 1.30551
# ...
# Epoch 148/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1996 - accuracy: 0.5904
# Epoch 148: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.1990 - accuracy: 0.5902 - val_loss: 1.3154 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 149/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1966 - accuracy: 0.5955
# Epoch 149: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.1962 - accuracy: 0.5953 - val_loss: 1.3154 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 150/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2004 - accuracy: 0.5871
# Epoch 150: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2012 - accuracy: 0.5869 - val_loss: 1.3166 - val_accuracy: 0.5488 - lr: 1.0000e-06
# Epoch 151/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2127 - accuracy: 0.5881
# Epoch 151: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2127 - accuracy: 0.5881 - val_loss: 1.3137 - val_accuracy: 0.5493 - lr: 1.0000e-06
# Epoch 152/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2060 - accuracy: 0.5875
# Epoch 152: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2068 - accuracy: 0.5873 - val_loss: 1.3133 - val_accuracy: 0.5493 - lr: 1.0000e-06
# Epoch 153/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2002 - accuracy: 0.5879
# Epoch 153: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2002 - accuracy: 0.5879 - val_loss: 1.3139 - val_accuracy: 0.5493 - lr: 1.0000e-06
# Epoch 154/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.1994 - accuracy: 0.5898
# Epoch 154: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.1995 - accuracy: 0.5893 - val_loss: 1.3146 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 155/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2010 - accuracy: 0.5901
# Epoch 155: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2009 - accuracy: 0.5901 - val_loss: 1.3150 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 156/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2012 - accuracy: 0.5858
# Epoch 156: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2012 - accuracy: 0.5858 - val_loss: 1.3159 - val_accuracy: 0.5531 - lr: 1.0000e-06
# Epoch 157/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2060 - accuracy: 0.5885
# Epoch 157: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2061 - accuracy: 0.5887 - val_loss: 1.3157 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 158/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2017 - accuracy: 0.5902
# Epoch 158: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2017 - accuracy: 0.5902 - val_loss: 1.3158 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 159/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2026 - accuracy: 0.5901
# Epoch 159: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2026 - accuracy: 0.5901 - val_loss: 1.3135 - val_accuracy: 0.5536 - lr: 1.0000e-06
# Epoch 160/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2068 - accuracy: 0.5898
# Epoch 160: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2068 - accuracy: 0.5898 - val_loss: 1.3181 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 161/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2053 - accuracy: 0.5902
# Epoch 161: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2049 - accuracy: 0.5902 - val_loss: 1.3146 - val_accuracy: 0.5483 - lr: 1.0000e-06
# Epoch 162/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2044 - accuracy: 0.5883
# Epoch 162: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2044 - accuracy: 0.5883 - val_loss: 1.3153 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 163/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2041 - accuracy: 0.5898
# Epoch 163: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 35ms/step - loss: 1.2042 - accuracy: 0.5897 - val_loss: 1.3145 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 164/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2075 - accuracy: 0.5884
# Epoch 164: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2073 - accuracy: 0.5886 - val_loss: 1.3132 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 165/200
# 132/132 [==============================] - ETA: 0s - loss: 1.1990 - accuracy: 0.5927
# Epoch 165: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.1990 - accuracy: 0.5927 - val_loss: 1.3108 - val_accuracy: 0.5547 - lr: 1.0000e-06
# Epoch 166/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2014 - accuracy: 0.5900
# Epoch 166: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2014 - accuracy: 0.5900 - val_loss: 1.3167 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 167/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.1980 - accuracy: 0.5880
# Epoch 167: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.1967 - accuracy: 0.5885 - val_loss: 1.3100 - val_accuracy: 0.5547 - lr: 1.0000e-06
# Epoch 168/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2042 - accuracy: 0.5871
# Epoch 168: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2036 - accuracy: 0.5876 - val_loss: 1.3137 - val_accuracy: 0.5536 - lr: 1.0000e-06
# Epoch 169/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2026 - accuracy: 0.5903
# Epoch 169: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2029 - accuracy: 0.5897 - val_loss: 1.3114 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 170/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2013 - accuracy: 0.5918
# Epoch 170: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2013 - accuracy: 0.5918 - val_loss: 1.3103 - val_accuracy: 0.5541 - lr: 1.0000e-06
# Epoch 171/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2072 - accuracy: 0.5906
# Epoch 171: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2072 - accuracy: 0.5906 - val_loss: 1.3122 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 172/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2098 - accuracy: 0.5889
# Epoch 172: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2087 - accuracy: 0.5892 - val_loss: 1.3147 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 173/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2109 - accuracy: 0.5860
# Epoch 173: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2109 - accuracy: 0.5860 - val_loss: 1.3139 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 174/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2012 - accuracy: 0.5921
# Epoch 174: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2012 - accuracy: 0.5921 - val_loss: 1.3112 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 175/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2019 - accuracy: 0.5903
# Epoch 175: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2019 - accuracy: 0.5903 - val_loss: 1.3136 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 176/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2036 - accuracy: 0.5887
# Epoch 176: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2045 - accuracy: 0.5880 - val_loss: 1.3155 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 177/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2070 - accuracy: 0.5898
# Epoch 177: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2075 - accuracy: 0.5899 - val_loss: 1.3126 - val_accuracy: 0.5531 - lr: 1.0000e-06
# Epoch 178/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2041 - accuracy: 0.5881
# Epoch 178: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.2041 - accuracy: 0.5882 - val_loss: 1.3119 - val_accuracy: 0.5536 - lr: 1.0000e-06
# Epoch 179/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2088 - accuracy: 0.5885
# Epoch 179: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2088 - accuracy: 0.5885 - val_loss: 1.3141 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 180/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1999 - accuracy: 0.5908
# Epoch 180: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.2011 - accuracy: 0.5907 - val_loss: 1.3092 - val_accuracy: 0.5557 - lr: 1.0000e-06
# Epoch 181/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2040 - accuracy: 0.5869
# Epoch 181: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2040 - accuracy: 0.5869 - val_loss: 1.3109 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 182/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2040 - accuracy: 0.5916
# Epoch 182: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2040 - accuracy: 0.5916 - val_loss: 1.3133 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 183/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2016 - accuracy: 0.5917
# Epoch 183: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2016 - accuracy: 0.5917 - val_loss: 1.3124 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 184/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2053 - accuracy: 0.5882
# Epoch 184: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2053 - accuracy: 0.5882 - val_loss: 1.3145 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 185/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1963 - accuracy: 0.5929
# Epoch 185: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.1967 - accuracy: 0.5926 - val_loss: 1.3122 - val_accuracy: 0.5493 - lr: 1.0000e-06
# Epoch 186/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1986 - accuracy: 0.5910
# Epoch 186: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2001 - accuracy: 0.5908 - val_loss: 1.3095 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 187/200
# 132/132 [==============================] - ETA: 0s - loss: 1.1994 - accuracy: 0.5908
# Epoch 187: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.1994 - accuracy: 0.5908 - val_loss: 1.3121 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 188/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2028 - accuracy: 0.5920
# Epoch 188: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2029 - accuracy: 0.5920 - val_loss: 1.3134 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 189/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2069 - accuracy: 0.5868
# Epoch 189: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2069 - accuracy: 0.5868 - val_loss: 1.3139 - val_accuracy: 0.5504 - lr: 1.0000e-06
# Epoch 190/200
# 132/132 [==============================] - ETA: 0s - loss: 1.1967 - accuracy: 0.5945
# Epoch 190: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 32ms/step - loss: 1.1967 - accuracy: 0.5945 - val_loss: 1.3116 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 191/200
# 130/132 [============================>.] - ETA: 0s - loss: 1.2006 - accuracy: 0.5904
# Epoch 191: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.2014 - accuracy: 0.5902 - val_loss: 1.3159 - val_accuracy: 0.5499 - lr: 1.0000e-06
# Epoch 192/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2008 - accuracy: 0.5915
# Epoch 192: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2008 - accuracy: 0.5915 - val_loss: 1.3128 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 193/200
# 132/132 [==============================] - ETA: 0s - loss: 1.1975 - accuracy: 0.5894
# Epoch 193: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.1975 - accuracy: 0.5894 - val_loss: 1.3139 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 194/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1928 - accuracy: 0.5940
# Epoch 194: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.1929 - accuracy: 0.5943 - val_loss: 1.3124 - val_accuracy: 0.5520 - lr: 1.0000e-06
# Epoch 195/200
# 132/132 [==============================] - ETA: 0s - loss: 1.1952 - accuracy: 0.5927
# Epoch 195: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.1952 - accuracy: 0.5927 - val_loss: 1.3127 - val_accuracy: 0.5531 - lr: 1.0000e-06
# Epoch 196/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1994 - accuracy: 0.5930
# Epoch 196: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.1998 - accuracy: 0.5930 - val_loss: 1.3117 - val_accuracy: 0.5515 - lr: 1.0000e-06
# Epoch 197/200
# 132/132 [==============================] - ETA: 0s - loss: 1.2074 - accuracy: 0.5854
# Epoch 197: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2074 - accuracy: 0.5854 - val_loss: 1.3125 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 198/200
# 132/132 [==============================] - ETA: 0s - loss: 1.1977 - accuracy: 0.5892
# Epoch 198: val_loss did not improve from 1.30551
# 132/132 [==============================] - 5s 34ms/step - loss: 1.1977 - accuracy: 0.5892 - val_loss: 1.3116 - val_accuracy: 0.5509 - lr: 1.0000e-06
# Epoch 199/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.1985 - accuracy: 0.5898
# Epoch 199: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 33ms/step - loss: 1.1974 - accuracy: 0.5901 - val_loss: 1.3122 - val_accuracy: 0.5525 - lr: 1.0000e-06
# Epoch 200/200
# 131/132 [============================>.] - ETA: 0s - loss: 1.2031 - accuracy: 0.5874
# Epoch 200: val_loss did not improve from 1.30551
# 132/132 [==============================] - 4s 34ms/step - loss: 1.2035 - accuracy: 0.5871 - val_loss: 1.3147 - val_accuracy: 0.5520 - lr: 1.0000e-06
# El mejor modelo se encuentra en: /workspace/COMPUTERVISIONPROYECT/experiment_results/ffNN/ffNN_best_model_execution_trace/model.keras

# %% [markdown]
# # Validation
# Compute validation metrics.

# %%
predictions = model.predict(valid_dataset)
category_names = np.array(list(categories.values()))
y_pred = category_names[predictions.argmax(axis=1)]

y_true = []

for images_batch, labels_batch in valid_dataset:
    labels_np = labels_batch.numpy()
    
    true_indices = np.argmax(labels_np, axis=1)
    batch_labels = category_names[true_indices]
    
    y_true.extend(batch_labels)
# Out:
# 15/15 [==============================] - 0s 9ms/step
# 2026-01-13 20:09:44.982174: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 2064062119857017835
# 2026-01-13 20:09:45.035799: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories)

# %%
ll = []
# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    ll.append(pd.Series([recall, precision, specificity, f1_score], name=categories[idx], index=["Recall", "Precision", "Specificity", "F1 Score"]))
ll = pd.DataFrame(ll)
ll = pd.concat([categories_count, ll, pd.Series([EXPERIMENT_NAME for _ in categories], name='Experiment', index=categories.values())],axis=1)
ll.index.name='Category'
ll = ll.reset_index().set_index(['Experiment','Category'])
ll
# Out:
# Mean Accuracy: 55.200%
# Mean Recall: 50.906%
# Mean Precision: 63.669%
#                                                          Size    Recall  \
# Experiment                           Category
# ffNN/ffNN_best_model_execution_trace Building            3235  0.587744
#                                      Small car           2992  0.861446
#                                      Truck               1989  0.158371
#                                      Bus                 1591  0.440678
#                                      Shipping container  1371  0.532895
#                                      Storage tank        1322  0.551020
#                                      Dump truck          1112  0.411290
#                                      Motorboat            962  0.551402
#                                      Excavator            710  0.569620
#                                      Fishing vessel       635  0.619718
#                                      Cargo plane          571  0.796875
#                                      Pylon                281  0.354839
#                                      Helipad              100  0.181818
#
#                                                          Precision  \
# Experiment                           Category
# ffNN/ffNN_best_model_execution_trace Building             0.698675
#                                      Small car            0.479062
#                                      Truck                0.296610
#                                      Bus                  0.445714
#                                      Shipping container   0.509434
#                                      Storage tank         0.771429
#                                      Dump truck           0.476636
#                                      Motorboat            0.584158
#                                      Excavator            0.592105
#                                      Fishing vessel       0.656716
#                                      Cargo plane          0.980769
#                                      Pylon                0.785714
#                                      Helipad              1.000000
#
#                                                          Specificity  F1 Score
# Experiment                           Category
# ffNN/ffNN_best_model_execution_trace Building               0.939974  0.638427
#                                      Small car              0.798445  0.615716
#                                      Truck                  0.949819  0.206490
#                                      Bus                    0.942874  0.443182
#                                      Shipping container     0.954730  0.520900
#                                      Storage tank           0.986111  0.642857
#                                      Dump truck             0.968018  0.441558
#                                      Motorboat              0.976244  0.567308
#                                      Excavator              0.982739  0.580645
#                                      Fishing vessel         0.987251  0.637681
#                                      Cargo plane            0.999448  0.879310
#                                      Pylon                  0.998373  0.488889
#                                      Helipad                1.000000  0.307692

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

plt.title('Accuracy & Loss')
ax1.set_xlabel('Epoch')

color_acc = 'blue'
ax1.set_ylabel('Accuracy', color=color_acc)
ax1.plot(h.history['accuracy'], label='Train Accuracy', color='blue', marker='.')
ax1.plot(h.history['val_accuracy'], label='Validation Accuracy', color='tab:blue', linestyle='--', marker='.')
ax1.tick_params(axis='y', labelcolor=color_acc)
ax1.grid(True, linestyle='--', alpha=0.5)

ax2 = ax1.twinx()  
color_loss = 'orange'
ax2.set_ylabel('Loss', color=color_loss)
ax2.plot(h.history['loss'], label='Train Loss', color='orange', marker='.')
ax2.plot(h.history['val_loss'], label='Validation Loss', color='tab:orange', linestyle='--', marker='.')
ax2.tick_params(axis='y', labelcolor=color_loss)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(lines1 + lines2, labels1 + labels2, loc='center left', frameon=True, fontsize='small')

fig.tight_layout()
plt.show()

# %% [markdown]
# # Testing
# Try to improve the results provided in the competition.

# %%
anns = []
for (dirpath, dirnames, filenames) in os.walk(os.path.join(XVIEW_RECOGNITION_PATH, 'xview_recognition/xview_test')):
    for filename in filenames:
        image = GenericImage(os.path.join(dirpath,filename))
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))

# %%
model.load_weights('model.keras')
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data

# %%
with open("prediction.json", "w") as outfile:
    json.dump(predictions_data, outfile)
