# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1:
# - Alumno 2:
# - Alumno 3:
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/2DDPE2zHw5dbM3G](https://drive.upm.es/s/2DDPE2zHw5dbM3G)

# %%
EXPERIMENT_NAME='TL/03_xception_without_tl'
assert(not EXPERIMENT_NAME is None)

import tensorflow as tf
import uuid
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import warnings
import rasterio
import json
import glob
import shutil

# Reduce TF warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Activation, Rescaling
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.layers import Dense, Flatten, Input, Dropout, BatchNormalization
from tensorflow.keras.callbacks import TerminateOnNaN, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import confusion_matrix

# %matplotlib inline
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2026-01-09 15:23:41.870152: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-09 15:23:41.877902: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-09 15:23:41.887157: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8473] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-09 15:23:41.890211: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1471] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-09 15:23:41.897077: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767972223.325468  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767972223.357290  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767972223.358723  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
PROJECT_PATH = "/workspace/COMPUTERVISIONPROYECT"
DATASET_NAME = 'stratified'

XVIEW_RECOGNITION_PATH = os.path.join(PROJECT_PATH, "data/xview_recognition")

EXPERIMENT_PATH = os.path.join(PROJECT_PATH, "experiment_results", EXPERIMENT_NAME)
EXPERIMENT_RESULTS = os.path.join(EXPERIMENT_PATH, "results")
assert(not os.path.exists(EXPERIMENT_PATH))
if not os.path.exists(EXPERIMENT_PATH):
    os.mkdir(EXPERIMENT_PATH)
    os.mkdir(EXPERIMENT_RESULTS)
CHECKPOINT_DIR = os.path.join(EXPERIMENT_PATH, 'model_checkpoints')
os.makedirs(CHECKPOINT_DIR, exist_ok=True)
BEST_WEIGHTS_FILENAME_PATTERN = os.path.join(CHECKPOINT_DIR, 'epoch_{epoch:03d}-val_loss_{val_loss:.4f}.keras')
MODEL_PATH = os.path.join(EXPERIMENT_PATH, 'model.keras')

CM_PATH = os.path.join(EXPERIMENT_RESULTS, 'cm.png')
METRICS_PATH = os.path.join(EXPERIMENT_RESULTS, 'metrics.csv')
ACC_LOSS_PATH = os.path.join(EXPERIMENT_RESULTS, 'acc_loss.png')
TEST_PREDICTS_PATH = os.path.join(EXPERIMENT_RESULTS, 'prediction.json')
HISTORY_PATH = os.path.join(EXPERIMENT_RESULTS, 'history.csv')

TRAIN_SET_FILENAME = '_'.join([DATASET_NAME, 'train.tfrecord'])
VALIDATION_SET_FILENAME = '_'.join([DATASET_NAME, 'validation.tfrecord'])
TRAIN_SET_PATH = os.path.join(XVIEW_RECOGNITION_PATH, TRAIN_SET_FILENAME)
VALIDATION_SET_PATH = os.path.join(XVIEW_RECOGNITION_PATH, VALIDATION_SET_FILENAME)

# Tensorboard
LOG_DIR = os.path.join(EXPERIMENT_PATH, 'logs')
os.makedirs(LOG_DIR, exist_ok=True)

SYMLINK_PATH = os.path.join('/workspace', 'tensorboard_logs')
if os.path.islink(SYMLINK_PATH):
    os.unlink(SYMLINK_PATH)
os.symlink(LOG_DIR, SYMLINK_PATH)

## Hyperparameters
BATCH_SIZE = 64
LEARNING_RATE = 1e-3
WEIGHT_DECAY = None
DROPOUT_RATE = 0.5
REGULARIZER_PENALTY = None
EPOCHS = 20

categories = {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}

# %% [markdown]
# # Required classes and functions

# %%
class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
def draw_confusion_matrix(cm, categories, save_path=None, exp_name=None):
    # Draw confusion matrix
    fig = plt.figure(figsize=[3.2*pow(len(categories), 0.5), 2.4*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.colormaps['Blues'])
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(15-pow(len(categories), 0.5)))
    fig.tight_layout()

    if save_path:
        if exp_name:
            plt.title(exp_name)
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        print(f"Gráfico guardado en: {save_path}")

    plt.show()

# 0. La usamos para las imágenes de test
def load_geoimage(filename_tensor):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    filename = filename_tensor
    src_raster = rasterio.open(filename, 'r')

    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img

# 1. Función para decodificar los ejemplos del archivo
def _parse_image_function(example_proto):
    feature_description = {
        'height': tf.io.FixedLenFeature([], tf.int64),
        'width': tf.io.FixedLenFeature([], tf.int64),
        'depth': tf.io.FixedLenFeature([], tf.int64),
        'category_id': tf.io.FixedLenFeature([], tf.int64),
        'image_raw': tf.io.FixedLenFeature([], tf.string),
    }
    
    features = tf.io.parse_single_example(example_proto, feature_description)
    
    image = tf.io.decode_raw(features['image_raw'], out_type=tf.uint8)
    shape = [features['height'], features['width'], features['depth']]
    image = tf.reshape(image, shape)
    image = tf.cast(image, tf.float32)
    
    image = tf.image.resize(image, [224, 224])
    
    category_id = tf.cast(features['category_id'], tf.int32)
    label = tf.one_hot(category_id, depth=len(categories))
    
    return image, label

# 2. Función para crear el dataset
def create_tfrecord_dataset(filenames, batch_size, do_shuffle=False):
    # Lee los archivos TFRecord. Puede leer de múltiples archivos en paralelo.
    dataset = tf.data.TFRecordDataset(filenames, num_parallel_reads=tf.data.AUTOTUNE)
    
    dataset = dataset.map(_parse_image_function, num_parallel_calls=tf.data.AUTOTUNE)
    # dataset = dataset.cache()
    
    if do_shuffle:
        dataset = dataset.shuffle(buffer_size=1000)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
    
    return dataset

# %% [markdown]
# # Datasets definition

# %%
train_dataset = create_tfrecord_dataset([TRAIN_SET_PATH], BATCH_SIZE, do_shuffle=True)
valid_dataset = create_tfrecord_dataset([VALIDATION_SET_PATH], BATCH_SIZE)
# Out:
# I0000 00:00:1767972223.546183  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767972223.549413  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767972223.551495  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767972223.674105  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767972223.675101  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1767972223.675925  390537 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-01-09 15:23:43.676978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10255 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5070 Ti, pci bus id: 0000:01:00.0, compute capability: 12.0

# %%
y_train_labels = []
for _,label_idxs in train_dataset:
    y_train_labels += list(label_idxs.numpy().argmax(axis=1))

index,freqs = np.unique(y_train_labels, return_counts=True)
categories_count = pd.Series(freqs, index=[categories[idx] for idx in index], name='Size').sort_values(ascending=False)

categories_count
# Out:
# 2026-01-09 15:23:46.214924: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Building              3235
# Small car             2992
# Truck                 1989
# Bus                   1591
# Shipping container    1371
# Storage tank          1322
# Dump truck            1112
# Motorboat              962
# Excavator              710
# Fishing vessel         635
# Cargo plane            571
# Pylon                  281
# Helipad                100
# Name: Size, dtype: int64

# %% [markdown]
# # Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
from tensorflow.keras.applications import Xception
from tensorflow.keras.applications.xception import preprocess_input

base_model = Xception(
    include_top=False,
    weights=None,
    input_shape=(224, 224, 3)
)

for layer in base_model.layers:
    layer.trainable = True

model = Sequential(name=EXPERIMENT_NAME)
model.add(base_model)
model.add(Flatten(name='Flatten'))

model.add(Dense(256, activation='relu'))
model.add(Dropout(DROPOUT_RATE))
model.add(Dense(len(categories), activation='softmax'))

model.summary()
# Out:
# Model: "TL/03_xception_without_tl"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  Flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 13)                3341
#
# =================================================================
# Total params: 46555189 (177.59 MB)
# Trainable params: 46500661 (177.39 MB)
# Non-trainable params: 54528 (213.00 KB)
# _________________________________________________________________

# %%
opt = Adam(learning_rate=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
model.compile(
    optimizer=opt,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Callbacks
model_checkpoint = ModelCheckpoint(
    filepath=BEST_WEIGHTS_FILENAME_PATTERN,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True
)

tensorboard_callback = TensorBoard(
    log_dir=LOG_DIR,
    histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=0
)

reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-6)
terminate = TerminateOnNaN()
early_stop = EarlyStopping('val_accuracy', patience=EPOCHS, verbose=1, restore_best_weights=False)
callbacks = [reduce_lr, early_stop, terminate, model_checkpoint, tensorboard_callback]

# %%
print('Training model')
h = model.fit(train_dataset, 
              validation_data=valid_dataset, 
              epochs=EPOCHS, 
              callbacks=callbacks, 
              verbose=1)

history_df = pd.DataFrame(model.history.history).reset_index(names=['epoch'])
history_df['checkpoint'] = False

checkpoints = glob.glob(os.path.join(CHECKPOINT_DIR, '*.keras'))

if checkpoints:
    # Copiamos el mejor modelo en la ruta {EXPERIMENT_PATH}/model.keras
    # Ordenar los archivos por el valor de 'val_loss' (que está en el nombre)
    # y coger el primero (el que tenga el valor más bajo)
    BEST_WEIGHTS_FILENAME = min(checkpoints, key=lambda x: float(x.split('val_loss_')[1].replace('.keras', '')))
    model.load_weights(BEST_WEIGHTS_FILENAME)
    model.save(MODEL_PATH)

    print(f"El mejor modelo se encuentra en: {MODEL_PATH}")
else:
    print("No se encontraron checkpoints.")

history_df.to_csv(HISTORY_PATH, index=False)
print(f"El historial se encuentra en: {HISTORY_PATH}")
# Out:
# Training model
# Epoch 1/20
# ''+ptx85+ptx85' is not a recognized feature for this target' is not a recognized feature for this target (ignoring feature)
#  (ignoring feature)
# ''+ptx85+ptx85' is not a recognized feature for this target' is not a recognized feature for this target (ignoring feature)
#  (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# 2026-01-09 15:23:54.017996: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90701
# W0000 00:00:1767972234.054501  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.056372  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.063083  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.063431  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.063858  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.064395  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.070248  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.071082  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.071838  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.072834  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.073949  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.075275  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.080772  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1767972234.190805  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.192356  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.194548  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.196633  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.198522  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.200517  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.202832  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.204322  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.207083  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.210135  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.211921  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.214920  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.217025  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.218976  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.221199  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.230197  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.233504  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.237461  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.264604  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.266616  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.267259  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.267669  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.268336  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.268988  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.269651  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.270996  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.271735  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.272718  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.273706  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.274728  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.275758  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.276900  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.278142  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.282626  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.283835  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.284967  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.286521  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.288070  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.290417  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.293060  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.295600  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.297140  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.299855  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.301734  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.304140  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.306486  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.307729  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.310963  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.312375  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.313695  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.317624  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.326066  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.330287  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.331365  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.334889  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.338135  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.339695  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.342847  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.345169  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.347251  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.351040  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.355790  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.359049  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.361842  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.365252  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.367919  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.370954  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.373818  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.378666  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.394952  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.395224  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.395491  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.395822  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.396231  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.396905  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.397454  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.397988  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.398533  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.399195  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.399953  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.400717  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.401404  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.402061  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.402693  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.404767  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.405258  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.405731  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.407000  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.408271  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.409082  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.410542  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.411612  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.412344  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.413782  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.415620  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.417092  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.418272  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.419954  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.421464  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.422824  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.424192  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.425989  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.430840  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.432414  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.433345  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.435357  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.437104  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.438411  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.440233  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.441432  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.442701  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.445135  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.447485  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.449526  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.451500  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.454097  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.456636  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.459145  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.462147  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.465116  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.470815  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.471981  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.472327  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.472739  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.473036  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.473473  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.473849  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.474222  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.474616  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.475064  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.475492  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.476051  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.476889  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.477414  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.477903  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.479896  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.480526  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.481105  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.481826  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.483150  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.484275  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.485344  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.486345  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.487482  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.488811  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.490119  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.491740  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.493025  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.494676  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.496342  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.498039  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.499613  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.501725  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.504309  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.511443  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.512936  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.514362  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.516099  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.518993  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.521213  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.523306  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.525825  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.528498  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.531071  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.534987  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.539589  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.542291  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.546172  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.551543  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.556555  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.559630  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.563907  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2026-01-09 15:23:54.569831: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.68GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1767972234.571529  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.572757  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.573180  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.573677  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.574293  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.574901  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.575467  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.576252  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.577040  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.577868  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.578550  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.579397  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.580065  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.580980  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.581873  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.583082  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.584025  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.585076  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.587990  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.593095  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.593590  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.594015  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.594514  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.595133  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.595723  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.596284  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.596966  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.597498  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.598331  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.599103  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.600175  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.601027  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.601929  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.602809  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.603714  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.604456  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.605499  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.608177  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.613871  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.629733  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.630203  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.630660  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.630930  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.631295  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.631596  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.632348  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.632905  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.633240  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.633488  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.633771  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.634046  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.634322  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.634610  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.636579  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.637175  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.637742  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.638369  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.639171  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.639980  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.640708  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.641578  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.642284  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.643444  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.644567  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.645725  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.646611  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.647810  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.649030  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.650589  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.651810  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.653235  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.658716  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.659125  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.659690  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.660352  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.660779  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.661172  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.661641  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.662097  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.662641  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.663124  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.663533  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.663908  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.664518  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.665143  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.666147  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.667043  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.667722  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.668561  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2026-01-09 15:23:54.672363: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.52GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# W0000 00:00:1767972234.674381  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.675094  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.675872  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.676765  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.677701  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.678532  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.679349  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.680299  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.681285  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.682240  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.683785  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.685265  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.686034  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.686799  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.688014  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.689390  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.690777  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972234.692423  390630 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2026-01-09 15:23:54.700666: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.97GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767972235.154666  390631 service.cc:146] XLA service 0x7f3f18fab0a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767972235.154693  390631 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 5070 Ti, Compute Capability 12.0
# 2026-01-09 15:23:55.159415: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# I0000 00:00:1767972235.220463  390631 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1767972235.550655  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.551420  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.552164  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.552945  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.554354  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.555196  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.555996  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.556741  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.557461  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.558425  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.569010  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.572665  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.575605  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1767972235.773415  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.774691  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.775364  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.777256  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.777890  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.778515  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.782147  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.783814  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.786126  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.789062  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.794390  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.797897  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972235.801561  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2026-01-09 15:23:55.805501: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.77GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# W0000 00:00:1767972236.009749  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.010294  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.010736  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.011205  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.011694  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.012149  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.012586  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.013035  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.013461  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.014008  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.014682  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.015393  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972236.016127  390631 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# ...
# W0000 00:00:1767972291.983574  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.984122  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.984584  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.985331  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.986089  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.987463  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.988471  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.989268  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.990256  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.991246  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.992453  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.993705  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.996492  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972291.997360  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.025608  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.025853  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.026046  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.026388  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.026604  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.026816  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.027071  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.027343  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.027596  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.027874  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.028137  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.028440  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.028713  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.029070  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.029544  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.033043  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.033235  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.033435  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.033564  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.033737  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.033920  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.034066  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.034211  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.034364  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.034526  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.034682  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.034850  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.035044  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.035223  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.035404  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038072  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038218  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038325  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038431  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038553  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038677  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038801  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.038969  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.039176  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.039323  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.039613  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.039777  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.040159  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.040350  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.040585  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.043335  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.046408  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.046766  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.046910  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.047028  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.047156  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.047286  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.047394  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.047521  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.047620  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.047826  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.048017  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.048258  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.048453  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767972292.048576  390633 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# 2026-01-09 15:24:52.051056: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 264/264 [==============================] - 70s 206ms/step - loss: 2.4686 - accuracy: 0.2741 - val_loss: 2.5109 - val_accuracy: 0.1915 - lr: 0.0010
# Epoch 2/20
# 264/264 [==============================] - ETA: 0s - loss: 1.8468 - accuracy: 0.3850
# Epoch 2: val_loss improved from 2.51092 to 2.10370, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/model_checkpoints/epoch_002-val_loss_2.1037.keras
# 264/264 [==============================] - 49s 187ms/step - loss: 1.8468 - accuracy: 0.3850 - val_loss: 2.1037 - val_accuracy: 0.3504 - lr: 0.0010
# Epoch 3/20
# 264/264 [==============================] - ETA: 0s - loss: 1.6789 - accuracy: 0.4277
# Epoch 3: val_loss improved from 2.10370 to 2.04436, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/model_checkpoints/epoch_003-val_loss_2.0444.keras
# 264/264 [==============================] - 50s 188ms/step - loss: 1.6789 - accuracy: 0.4277 - val_loss: 2.0444 - val_accuracy: 0.3125 - lr: 0.0010
# Epoch 4/20
# 264/264 [==============================] - ETA: 0s - loss: 1.6998 - accuracy: 0.4255
# Epoch 4: val_loss did not improve from 2.04436
# 264/264 [==============================] - 49s 186ms/step - loss: 1.6998 - accuracy: 0.4255 - val_loss: 5.3270 - val_accuracy: 0.2261 - lr: 0.0010
# Epoch 5/20
# 264/264 [==============================] - ETA: 0s - loss: 1.6632 - accuracy: 0.4490
# Epoch 5: val_loss did not improve from 2.04436
# 264/264 [==============================] - 49s 185ms/step - loss: 1.6632 - accuracy: 0.4490 - val_loss: 2.2610 - val_accuracy: 0.2795 - lr: 0.0010
# Epoch 6/20
# 264/264 [==============================] - ETA: 0s - loss: 1.5992 - accuracy: 0.4635
# Epoch 6: val_loss improved from 2.04436 to 1.77416, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/model_checkpoints/epoch_006-val_loss_1.7742.keras
# 264/264 [==============================] - 49s 184ms/step - loss: 1.5992 - accuracy: 0.4635 - val_loss: 1.7742 - val_accuracy: 0.3840 - lr: 0.0010
# Epoch 7/20
# 264/264 [==============================] - ETA: 0s - loss: 1.4648 - accuracy: 0.5041
# Epoch 7: val_loss improved from 1.77416 to 1.21012, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/model_checkpoints/epoch_007-val_loss_1.2101.keras
# 264/264 [==============================] - 49s 184ms/step - loss: 1.4648 - accuracy: 0.5041 - val_loss: 1.2101 - val_accuracy: 0.6021 - lr: 0.0010
# Epoch 8/20
# 264/264 [==============================] - ETA: 0s - loss: 1.3748 - accuracy: 0.5379
# Epoch 8: val_loss did not improve from 1.21012
# 264/264 [==============================] - 48s 182ms/step - loss: 1.3748 - accuracy: 0.5379 - val_loss: 1.3259 - val_accuracy: 0.5371 - lr: 0.0010
# Epoch 9/20
# 264/264 [==============================] - ETA: 0s - loss: 1.3063 - accuracy: 0.5583
# Epoch 9: val_loss did not improve from 1.21012
# 264/264 [==============================] - 48s 182ms/step - loss: 1.3063 - accuracy: 0.5583 - val_loss: 1.4214 - val_accuracy: 0.5349 - lr: 0.0010
# Epoch 10/20
# 264/264 [==============================] - ETA: 0s - loss: 1.3111 - accuracy: 0.5629
# Epoch 10: val_loss did not improve from 1.21012
# 264/264 [==============================] - 48s 183ms/step - loss: 1.3111 - accuracy: 0.5629 - val_loss: 1.8149 - val_accuracy: 0.4528 - lr: 0.0010
# Epoch 11/20
# 264/264 [==============================] - ETA: 0s - loss: 1.2240 - accuracy: 0.5867
# Epoch 11: val_loss did not improve from 1.21012
# 264/264 [==============================] - 49s 184ms/step - loss: 1.2240 - accuracy: 0.5867 - val_loss: 1.3931 - val_accuracy: 0.5627 - lr: 0.0010
# Epoch 12/20
# 264/264 [==============================] - ETA: 0s - loss: 1.1328 - accuracy: 0.6147
# Epoch 12: val_loss improved from 1.21012 to 1.03707, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/model_checkpoints/epoch_012-val_loss_1.0371.keras
# 264/264 [==============================] - 48s 183ms/step - loss: 1.1328 - accuracy: 0.6147 - val_loss: 1.0371 - val_accuracy: 0.6597 - lr: 0.0010
# Epoch 13/20
# 264/264 [==============================] - ETA: 0s - loss: 1.1471 - accuracy: 0.6057
# Epoch 13: val_loss did not improve from 1.03707
# 264/264 [==============================] - 48s 183ms/step - loss: 1.1471 - accuracy: 0.6057 - val_loss: 1.2143 - val_accuracy: 0.6176 - lr: 0.0010
# Epoch 14/20
# 264/264 [==============================] - ETA: 0s - loss: 1.0962 - accuracy: 0.6228
# Epoch 14: val_loss did not improve from 1.03707
# 264/264 [==============================] - 48s 181ms/step - loss: 1.0962 - accuracy: 0.6228 - val_loss: 1.5668 - val_accuracy: 0.4725 - lr: 0.0010
# Epoch 15/20
# 264/264 [==============================] - ETA: 0s - loss: 1.0744 - accuracy: 0.6332
# Epoch 15: val_loss did not improve from 1.03707
# 264/264 [==============================] - 48s 183ms/step - loss: 1.0744 - accuracy: 0.6332 - val_loss: 1.0839 - val_accuracy: 0.6608 - lr: 0.0010
# Epoch 16/20
# 264/264 [==============================] - ETA: 0s - loss: 0.9597 - accuracy: 0.6697
# Epoch 16: val_loss improved from 1.03707 to 0.90523, saving model to /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/model_checkpoints/epoch_016-val_loss_0.9052.keras
# 264/264 [==============================] - 48s 183ms/step - loss: 0.9597 - accuracy: 0.6697 - val_loss: 0.9052 - val_accuracy: 0.6949 - lr: 0.0010
# Epoch 17/20
# 264/264 [==============================] - ETA: 0s - loss: 1.1365 - accuracy: 0.6345
# Epoch 17: val_loss did not improve from 0.90523
# 264/264 [==============================] - 48s 182ms/step - loss: 1.1365 - accuracy: 0.6345 - val_loss: 1.2519 - val_accuracy: 0.5904 - lr: 0.0010
# Epoch 18/20
# 264/264 [==============================] - ETA: 0s - loss: 0.8962 - accuracy: 0.6787
# Epoch 18: val_loss did not improve from 0.90523
# 264/264 [==============================] - 48s 183ms/step - loss: 0.8962 - accuracy: 0.6787 - val_loss: 0.9519 - val_accuracy: 0.6827 - lr: 0.0010
# Epoch 19/20
# 264/264 [==============================] - ETA: 0s - loss: 0.7830 - accuracy: 0.7159
# Epoch 19: val_loss did not improve from 0.90523
# 264/264 [==============================] - 48s 183ms/step - loss: 0.7830 - accuracy: 0.7159 - val_loss: 0.9482 - val_accuracy: 0.7072 - lr: 0.0010
# Epoch 20/20
# 264/264 [==============================] - ETA: 0s - loss: 0.7259 - accuracy: 0.7336
# Epoch 20: val_loss did not improve from 0.90523
# 264/264 [==============================] - 48s 181ms/step - loss: 0.7259 - accuracy: 0.7336 - val_loss: 1.0083 - val_accuracy: 0.6981 - lr: 0.0010
# El mejor modelo se encuentra en: /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/model.keras
# El historial se encuentra en: /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/results/history.csv

# %% [markdown]
# # Validation
# Compute validation metrics.

# %%
model = tf.keras.models.load_model(MODEL_PATH)
model.summary()
# Out:
# Model: "TL/03_xception_without_tl"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  Flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 256)               25690368
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 13)                3341
#
# =================================================================
# Total params: 46555189 (177.59 MB)
# Trainable params: 46500661 (177.39 MB)
# Non-trainable params: 54528 (213.00 KB)
# _________________________________________________________________

# %%
predictions = model.predict(valid_dataset)
category_names = np.array(list(categories.values()))
y_pred = category_names[predictions.argmax(axis=1)]

y_true = []

for images_batch, labels_batch in valid_dataset:
    labels_np = labels_batch.numpy()
    
    true_indices = np.argmax(labels_np, axis=1)
    batch_labels = category_names[true_indices]
    
    y_true.extend(batch_labels)
# Out:
# 30/30 [==============================] - 2s 41ms/step
# 2026-01-09 15:41:19.877602: I tensorflow/core/framework/local_rendezvous.cc:423] Local rendezvous recv item cancelled. Key hash: 10607471732421827420
# 2026-01-09 15:41:20.116503: I tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Compute the confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
draw_confusion_matrix(cm, categories, CM_PATH, EXPERIMENT_NAME)
# Out:
# Gráfico guardado en: /workspace/COMPUTERVISIONPROYECT/experiment_results/TL/03_xception_without_tl/results/cm.png

# %%
ll = []
# Compute the accuracy
correct_samples_class = np.diag(cm).astype(float)
total_samples_class = np.sum(cm, axis=1).astype(float)
total_predicts_class = np.sum(cm, axis=0).astype(float)
print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
global_acc = acc.mean()
print('Mean Recall: %.3f%%' % (acc.mean() * 100))
acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
global_recall = acc.mean()
print('Mean Precision: %.3f%%' % (acc.mean() * 100))
global_precision = acc.mean()
for idx in range(len(categories)):
    # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
    # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
    recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
    # Precision: proportion of predicted positive cases that were truly real positives.
    precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
    # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
    specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
    # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
    # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
    f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
    ll.append(pd.Series([recall, precision, specificity, f1_score], name=categories[idx], index=["Recall", "Precision", "Specificity", "F1 Score"]))
ll = pd.DataFrame(ll)
sizes_col=pd.Series(y_true).value_counts()
sizes_col.name="Size"
ll = pd.concat([sizes_col, ll, pd.Series([EXPERIMENT_NAME for _ in categories], name='Experiment', index=categories.values())],axis=1)
ll.index.name='Category'
ll = ll.reset_index().set_index(['Experiment','Category'])
ll['Accuracy'] = np.nan
ll.loc[(EXPERIMENT_NAME, 'Global'), ['Size', 'Recall', 'Precision', 'Accuracy']] = [ll.Size.sum().astype(int), global_recall, global_precision, global_acc]
ll = ll.sort_values('Size', ascending=False)
ll.to_csv(METRICS_PATH)
ll.transpose()
# Out:
# Mean Accuracy: 69.493%
# Mean Recall: 63.605%
# Mean Precision: 67.159%
# Experiment  TL/03_xception_without_tl                                      \
# Category                       Global    Building   Small car       Truck
# Size                      1875.000000  359.000000  332.000000  221.000000
# Recall                       0.671589    0.885794    0.891566    0.316742
# Precision                    0.671589    0.771845    0.725490    0.351759
# Specificity                       NaN    0.937995    0.927414    0.922007
# F1 Score                          NaN    0.824903    0.800000    0.333333
# Accuracy                     0.636047         NaN         NaN         NaN
#
# Experiment                                                           \
# Category            Bus Shipping container Storage tank  Dump truck
# Size         177.000000         152.000000   147.000000  124.000000
# Recall         0.418079           0.703947     0.700680    0.580645
# Precision      0.616667           0.694805     0.804688    0.533333
# Specificity    0.972909           0.972722     0.985532    0.964021
# F1 Score       0.498316           0.699346     0.749091    0.555985
# Accuracy            NaN                NaN          NaN         NaN
#
# Experiment                                                                \
# Category      Motorboat  Excavator Fishing vessel Cargo plane      Pylon
# Size         107.000000  79.000000      71.000000   64.000000  31.000000
# Recall         0.682243   0.797468       0.690141    0.859375   0.741935
# Precision      0.879518   0.732558       0.700000    1.000000   0.920000
# Specificity    0.994344   0.987194       0.988359    1.000000   0.998915
# F1 Score       0.768421   0.763636       0.695035    0.924370   0.821429
# Accuracy            NaN        NaN            NaN         NaN        NaN
#
# Experiment
# Category    Helipad
# Size           11.0
# Recall          0.0
# Precision       0.0
# Specificity     1.0
# F1 Score        0.0
# Accuracy        NaN

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

plt.title(f'Accuracy & Loss - {EXPERIMENT_NAME}')
ax1.set_xlabel('Epoch')

color_acc = 'blue'
ax1.set_ylabel('Accuracy', color=color_acc)
ax1.plot(h.history['accuracy'], label='Train Accuracy', color='blue', marker='.')
ax1.plot(h.history['val_accuracy'], label='Validation Accuracy', color='tab:blue', linestyle='--', marker='.')
ax1.tick_params(axis='y', labelcolor=color_acc)
ax1.grid(True, linestyle='--', alpha=0.5)

ax2 = ax1.twinx()  
color_loss = 'orange'
ax2.set_ylabel('Loss', color=color_loss)
ax2.plot(h.history['loss'], label='Train Loss', color='orange', marker='.')
ax2.plot(h.history['val_loss'], label='Validation Loss', color='tab:orange', linestyle='--', marker='.')
ax2.tick_params(axis='y', labelcolor=color_loss)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(lines1 + lines2, labels1 + labels2, loc='center left', frameon=True, fontsize='small')

fig.tight_layout()

plt.savefig(ACC_LOSS_PATH, bbox_inches='tight', dpi=300)

plt.show()

# %% [markdown]
# # Testing
# Try to improve the results provided in the competition.

# %%
anns = []
for (dirpath, dirnames, filenames) in os.walk(os.path.join(XVIEW_RECOGNITION_PATH, 'xview_test')):
    for filename in filenames:
        image = GenericImage(os.path.join(dirpath,filename))
        image.tile = np.array([0, 0, 224, 224])
        obj = GenericObject()
        obj.bb = (0, 0, 224, 224)
        obj.category = dirpath[dirpath.rfind('/')+1:]
        image.add_object(obj)
        anns.append(image)
print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 2365

# %%
model = tf.keras.models.load_model(MODEL_PATH)
predictions_data = {"images": {}, "annotations": {}}
for idx, ann in enumerate(anns):
    image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
    predictions_data["images"][idx] = image_data
    # Load image
    image = load_geoimage(ann.filename)
    for obj_pred in ann.objects:
        # Generate prediction
        warped_image = np.expand_dims(image, 0)
        predictions = model.predict(warped_image, verbose=0)
        # Save prediction
        pred_category = list(categories.values())[np.argmax(predictions)]
        pred_score = np.max(predictions)
        annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
        predictions_data["annotations"][idx] = annotation_data
# Out:
# W0000 00:00:1767973301.897408  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897456  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897479  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897504  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897539  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897569  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897607  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897645  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897690  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897725  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897763  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.897810  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.898803  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.898870  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.898922  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.898965  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899018  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899087  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899140  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899182  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899256  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899324  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899419  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899477  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899550  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899630  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899708  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.899779  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.903559  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.905895  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.905933  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.905958  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.905982  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906010  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906046  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906077  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906114  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906147  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906178  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906210  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906241  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906273  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906311  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906347  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.906387  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907703  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907741  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907768  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907800  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907832  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907863  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907893  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907926  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907959  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.907992  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.908023  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.908055  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.908088  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.908127  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.908170  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.908209  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909365  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909436  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909472  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909507  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909544  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909585  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909633  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909676  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909722  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909766  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909811  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909858  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909902  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.909958  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.910003  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.910054  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.911549  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.911635  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.911682  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.911754  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.911838  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.911924  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912010  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912101  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912184  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912274  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912316  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912360  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912444  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912525  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912633  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1767973301.912727  390627 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced

# %%
with open(TEST_PREDICTS_PATH, "w") as outfile:
    json.dump(predictions_data, outfile)
